# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf

# Import our input dataset
diabetes_df = pd.read_csv('diabetes.csv')
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Remove diabetes outcome target from features data
y = diabetes_df.Outcome
X = diabetes_df.drop(columns="Outcome")

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the logistic regression model
log_classifier = LogisticRegression(solver="lbfgs",max_iter=200)

# Train the model
log_classifier.fit(X_train,y_train)

# Evaluate the model
y_pred = log_classifier.predict(X_test)
print(f" Logistic regression model accuracy: {accuracy_score(y_test,y_pred):.3f}")
# Out:
#  Logistic regression model accuracy: 0.729

# %%
# Define the basic neural network model
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=8))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/50
# 2022-08-17 09:54:47.993873: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 18/18 [==============================] - 1s 2ms/step - loss: 0.8093 - accuracy: 0.4931
# Epoch 2/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.7447 - accuracy: 0.5434
# Epoch 3/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6935 - accuracy: 0.5799
# Epoch 4/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6520 - accuracy: 0.6285
# Epoch 5/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6188 - accuracy: 0.6597
# Epoch 6/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5930 - accuracy: 0.6840
# Epoch 7/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5714 - accuracy: 0.7101
# Epoch 8/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5559 - accuracy: 0.7431
# Epoch 9/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5414 - accuracy: 0.7465
# Epoch 10/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5303 - accuracy: 0.7535
# Epoch 11/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5205 - accuracy: 0.7587
# Epoch 12/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5128 - accuracy: 0.7587
# Epoch 13/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5059 - accuracy: 0.7622
# Epoch 14/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4996 - accuracy: 0.7639
# Epoch 15/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4944 - accuracy: 0.7674
# Epoch 16/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4898 - accuracy: 0.7726
# Epoch 17/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4856 - accuracy: 0.7708
# Epoch 18/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4817 - accuracy: 0.7743
# Epoch 19/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4785 - accuracy: 0.7743
# Epoch 20/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4754 - accuracy: 0.7760
# Epoch 21/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4728 - accuracy: 0.7795
# Epoch 22/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4706 - accuracy: 0.7795
# Epoch 23/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4678 - accuracy: 0.7812
# Epoch 24/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4658 - accuracy: 0.7812
# Epoch 25/50
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4640 - accuracy: 0.7795
# Epoch 26/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4618 - accuracy: 0.7812
# Epoch 27/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4601 - accuracy: 0.7812
# Epoch 28/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4582 - accuracy: 0.7830
# Epoch 29/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4571 - accuracy: 0.7812
# Epoch 30/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4555 - accuracy: 0.7830
# Epoch 31/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4544 - accuracy: 0.7830
# Epoch 32/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4532 - accuracy: 0.7830
# Epoch 33/50
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4521 - accuracy: 0.7865
# Epoch 34/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4511 - accuracy: 0.7865
# Epoch 35/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4502 - accuracy: 0.7882
# Epoch 36/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4492 - accuracy: 0.7882
# Epoch 37/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4482 - accuracy: 0.7865
# Epoch 38/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4475 - accuracy: 0.7882
# Epoch 39/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4466 - accuracy: 0.7899
# Epoch 40/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4463 - accuracy: 0.7865
# Epoch 41/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4450 - accuracy: 0.7865
# Epoch 42/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4446 - accuracy: 0.7882
# Epoch 43/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4439 - accuracy: 0.7865
# Epoch 44/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4435 - accuracy: 0.7882
# Epoch 45/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4428 - accuracy: 0.7865
# Epoch 46/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4419 - accuracy: 0.7882
# Epoch 47/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4413 - accuracy: 0.7899
# Epoch 48/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4410 - accuracy: 0.7899
# Epoch 49/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4405 - accuracy: 0.7899
# Epoch 50/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4400 - accuracy: 0.7882
# 6/6 - 0s - loss: 0.4996 - accuracy: 0.7240 - 152ms/epoch - 25ms/step
# Loss: 0.4995780885219574, Accuracy: 0.7239583134651184
